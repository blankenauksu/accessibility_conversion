# %% [markdown]
# # Convert SWP slides
#
# Step 1 of 2: read a Scientific Word `.tex` file and write an accessible `*_slides.tex` file.
#
# After running this notebook, **edit the output in TeXShop** (add tags, fix structure), then run **`compile_slides.ipynb`**.
#
# Re-run this notebook only when the SWP source changes — it overwrites `*_slides.tex`.

# %%
import sys
from pathlib import Path

ROOT = Path(".").resolve()
PIPELINE = ROOT / "accessible_slides"
MATERIALS = ROOT / "905_materials"

if str(PIPELINE) not in sys.path:
    sys.path.insert(0, str(PIPELINE))

from convert_swp_slides import convert_swp_slides

# %%
SOURCE = "slides1fall25.tex"  # SWP file in 905_materials/

convert_swp_slides(
    SOURCE,
    title="Econ 905 -- Lecture 1",
    author="Your Name",
    date="Fall 2025",
    search_dirs=[MATERIALS],
)
